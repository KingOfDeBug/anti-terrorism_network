# %%
from graph import my_graph
from process_country import process_country
from process_web import process
from build_graph import build_graph
import pandas as pd
import numpy as np
import re

# %%
country_dict = process_country()

# %%
process(country_dict)

# %%
G = build_graph()

# %%
G.plot(country_dict)
